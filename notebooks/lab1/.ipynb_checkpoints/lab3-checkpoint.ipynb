# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Common imports
import numpy as np
import os

# To plot pretty figures
#%matplotlib inline
# import matplotlib as mpl
import matplotlib.pyplot as plt
# mpl.rc('axes', labelsize=14)
# mpl.rc('xtick', labelsize=12)
# mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "../."
CHAPTER_ID = "lab3"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)


def get_path(fig_name, fig_extension="png"):
    path = os.path.join(IMAGES_PATH, fig_name + "." + fig_extension)
    return path

# %%
from qiskit import QuantumCircuit,transpile
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_state_city

# %% [markdown]
# # Exercise 1
#
# Using Python and Qiskit, create a quantum circuit with only one qubit $\vert 1 \rangle$. Using Qiskit Aer, simulate the circuit using the state vector method and print the state vector. Measure the qubit and rerun the simulation. This time, plot the histogram.

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.save_statevector()

simulator = AerSimulator(method='statevector')
qc = transpile(qc, simulator)

# Run and get statevector
result = simulator.run(qc).result()
statevector = result.get_statevector(qc)
print(statevector)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
qc.measure_all()
simulator = AerSimulator(method='statevector')

qc = transpile(qc, simulator)
# Run and get counts
result = simulator.run(qc).result()
counts = result.get_counts(qc)
plot_histogram(counts)

# %% [markdown]
# # Exercise 2
#
# Modify the circuit from Exercise 1 to initialize the qubit to $\vert + \rangle$

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.save_statevector()

simulator = AerSimulator(method='statevector')
qc = transpile(qc, simulator)

# Run and get statevector
result = simulator.run(qc).result()
statevector = result.get_statevector(qc)
print(statevector)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
qc.measure_all()
simulator = AerSimulator(method='statevector')

qc = transpile(qc, simulator)
# Run and get counts
result = simulator.run(qc).result()
counts = result.get_counts(qc)
plot_histogram(counts)

# %% [markdown]
# # Exercise 3
#
# Create a quantum circuit with 4 qubits. Apply the Hadamard gate on all qubits and print the state vector. Measure the qubits and rerun the simulation. Plot the histogram.

# %%
qc = QuantumCircuit(4)
qc.h([0,1,2,3])
qc.save_statevector()

simulator = AerSimulator(method='statevector')
qc = transpile(qc, simulator)

# Run and get statevector
result = simulator.run(qc).result()
statevector = result.get_statevector(qc)
print(statevector)
# Out:
# Statevector([0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j,
#              0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j,
#              0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j],
#             dims=(2, 2, 2, 2))

# %%
qc.measure_all()
simulator = AerSimulator(method='statevector')

qc = transpile(qc, simulator)
# Run and get counts
result = simulator.run(qc).result()
counts = result.get_counts(qc)
plot_histogram(counts)

# %% [markdown]
# # Exercise 4
#
# Create a quantum circuit with 4 qubits. Apply the Hadamard gate on all qubits twice and print the state vector. Measure the qubits and rerun the simulation. Plot the histogram.

# %%
qc = QuantumCircuit(4)
qc.h([0,1,2,3])
qc.h([0,1,2,3])
qc.save_statevector()

simulator = AerSimulator(method='statevector')
qc = transpile(qc, simulator)

# Run and get statevector
result = simulator.run(qc).result()
statevector = result.get_statevector(qc)
print(statevector)
# Out:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2))

# %%
qc.measure_all()
simulator = AerSimulator(method='statevector')

qc = transpile(qc, simulator)
# Run and get counts
result = simulator.run(qc).result()
counts = result.get_counts(qc)
plot_histogram(counts)

# %% [markdown]
# # Exercise 5
#
# Create a quantum circuit with 2 qubits. Apply the Hadamard gate on qubit 0 and a Controlled-Not gate with control qubit 0 and target qubit 1. Print the state vector. Measure the qubits and rerun the simulation. Plot the histogram.

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.save_statevector()

simulator = AerSimulator(method='statevector')
qc = transpile(qc, simulator)

# Run and get statevector
result = simulator.run(qc).result()
statevector = result.get_statevector(qc)
print(statevector)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
qc.measure_all()
simulator = AerSimulator(method='statevector')

qc = transpile(qc, simulator)
# Run and get counts
result = simulator.run(qc).result()
counts = result.get_counts(qc)
plot_histogram(counts)

# %% [markdown]
# # Exercise 6

# %%
def not_gate(input_str):
    """ NOT gate.

    Parameters
        input_str (str): Input, encoded in qubit 0.

    Returns:
        QuantumCircuit: Output NOT circuit.
    """
    qc = QuantumCircuit(1)
    if input_str == '1':
        qc.x(0)
    qc.barrier()
    qc.x(0)
    return qc

# %%
def xor_gate(input_a, input_b):
    """ XOR gate.

    Parameters
        input_a (str): Input, encoded in qubit 0.
        input_b (str): Input, encoded in qubit 1.

    Returns:
        QuantumCircuit: Output XOR circuit
    """
    qc = QuantumCircuit(2)
    if input_a == '1':
        qc.x(0)
    if input_b == '1':
        qc.x(1)
    qc.barrier()
    qc.cx(0,1)
    return qc

# %%
def and_gate(input_a, input_b):
    qc = QuantumCircuit(3)
    if input_a == '1':
        qc.x(0)
    if input_b == '1':
        qc.x(1)
    qc.barrier()
    qc.ccx(0,1,2)
    return qc

# %%
def nand_gate(input_a, input_b):
    qc = QuantumCircuit(3)
    if input_a == '1':
        qc.x(0)
    if input_b == '1':
        qc.x(1)
    qc.barrier()
    qc.ccx(0,1,2)
    qc.x(2)
    return qc

# %%
def or_gate(input_a, input_b):
    qc = QuantumCircuit(3)
    if input_a == '1':
        qc.x(0)
    if input_b == '1':
        qc.x(1)
    qc.x(0)
    qc.x(1)
    qc.barrier()
    qc.ccx(0,1,2)
    qc.x(2)
    return qc

# %%
def measure(qc):
    qc.measure_all()

    # Transpile for simulator
    simulator = AerSimulator()
    qc = transpile(qc, simulator)
    
    # Run and get counts
    result = simulator.run(qc, shots=1, memory=True).result()
    memory = result.get_memory(qc)
    return memory

# %%
## Test NOT GATE
for inp in ['0', '1']:
    qc = not_gate(inp)
    out = measure(qc)
    print(f"NOT with input {inp} gives output {out}")
    fig = qc.draw(output = 'mpl')
    out_name = f"not_gate_{inp}"
    fig.savefig(
        get_path(out_name),
        bbox_inches='tight',
        pad_inches=0)
    display(fig)
    print('\n')
# Out:
# NOT with input 0 gives output ['1']
# NOT with input 1 gives output ['0']

# %%
## Test XOR Gate
for inpa in ['0', '1']:
    for inpb in ['0', '1']:
        qc = xor_gate(inpa,inpb)
        out = measure(qc)
        print(f"XOR with input {inpa} {inpb} gives output {out[0][0]}")
        fig = qc.draw(output = 'mpl')
        # out_name = f"not_gate_{inp}"
        # fig.savefig(
        #     get_path(out_name),
        #     bbox_inches='tight',
        #     pad_inches=0)
        display(fig)
        print('\n')
# Out:
# XOR with input 0 0 gives output 0
# XOR with input 0 1 gives output 1
# XOR with input 1 0 gives output 1
# XOR with input 1 1 gives output 0

# %%
## Test AND Gate
for inpa in ['0', '1']:
    for inpb in ['0', '1']:
        qc = and_gate(inpa,inpb)
        out = measure(qc)
        print(f"AND with input {inpa} {inpb} gives output {out[0][0]}")
        fig = qc.draw(output = 'mpl')
        # out_name = f"not_gate_{inp}"
        # fig.savefig(
        #     get_path(out_name),
        #     bbox_inches='tight',
        #     pad_inches=0)
        display(fig)
        print('\n')
# Out:
# AND with input 0 0 gives output 0
# AND with input 0 1 gives output 0
# AND with input 1 0 gives output 0
# AND with input 1 1 gives output 1

# %%
## Test NAND Gate
for inpa in ['0', '1']:
    for inpb in ['0', '1']:
        qc = nand_gate(inpa,inpb)
        out = measure(qc)
        print(f"NAND with input {inpa} {inpb} gives output {out[0][0]}")
        fig = qc.draw(output = 'mpl')
        # out_name = f"not_gate_{inp}"
        # fig.savefig(
        #     get_path(out_name),
        #     bbox_inches='tight',
        #     pad_inches=0)
        display(fig)
        print('\n')
# Out:
# NAND with input 0 0 gives output 1
# NAND with input 0 1 gives output 1
# NAND with input 1 0 gives output 1
# NAND with input 1 1 gives output 0

# %%
## Test OR Gate
for inpa in ['0', '1']:
    for inpb in ['0', '1']:
        qc = or_gate(inpa,inpb)
        out = measure(qc)
        print(f"OR with input {inpa} {inpb} gives output {out[0][0]}")
        fig = qc.draw(output = 'mpl')
        # out_name = f"not_gate_{inp}"
        # fig.savefig(
        #     get_path(out_name),
        #     bbox_inches='tight',
        #     pad_inches=0)
        display(fig)
        print('\n')
# Out:
# OR with input 0 0 gives output 0
# OR with input 0 1 gives output 1
# OR with input 1 0 gives output 1
# OR with input 1 1 gives output 1

# %% [markdown]
# # Exercise 7

# %%
qc = QuantumCircuit(4,2)
qc.x(0)
qc.x(1)
#encode inputs in qubit 0 and 1
qc.barrier()
qc.cx(0,2)
qc.cx(1,2)
qc.ccx(0,1,3)
qc.barrier()
qc.measure(2,0)
qc.measure(3,0)

# %%
import matplotlib.pyplot as plt

# %%
# Transpile for simulator
simulator = AerSimulator()
qc = transpile(qc, simulator)

# Run and get counts
result = simulator.run(qc, shots=1, memory=True).result()
counts = result.get_counts(qc)

# Create a single figure with 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Draw the circuit directly in subplot (a)
qc.draw(output="mpl", ax=axes[0])
axes[0].set_title("a)", y=-0.4)

# Plot histogram in subplot (b)
plot_histogram(counts, ax=axes[1])
axes[1].set_title("b)", y=-0.2)

plt.tight_layout()
plt.savefig(get_path("half_adder_both"), bbox_inches="tight", pad_inches=0)
plt.show()
